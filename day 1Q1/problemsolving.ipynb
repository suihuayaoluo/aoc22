# %%
sum = 0
max_sum=0 
intermediate = 0
total = []

f = open("data.txt", "r")

for i in f:
    if i != "\n":
        sum += int(i)
    else:
        total.append(sum)
        sum = 0

print (total)

for i in range (0,len(total)-1):
    if total[i] > max_sum:
        max_sum = total[i]

print (max_sum)
# Out:
# [61970, 52428, 31626, 48210, 60145, 37020, 49032, 46629, 18485, 51703, 57288, 51207, 49586, 57365, 40327, 19535, 34787, 66239, 43148, 57024, 51705, 36761, 57391, 55140, 29288, 41162, 66606, 39859, 53776, 44474, 41504, 40668, 57585, 47552, 46545, 53296, 32949, 38325, 42209, 56391, 42741, 25565, 44563, 45060, 49961, 39613, 42774, 48067, 45671, 31243, 51199, 55550, 29477, 60744, 56591, 58659, 47474, 56887, 48901, 37718, 45512, 26167, 52335, 38888, 19530, 30897, 45583, 54729, 16064, 56843, 51197, 41067, 20546, 32304, 37957, 57943, 30159, 51557, 59642, 55242, 44828, 48560, 45472, 49792, 43225, 45370, 34019, 51977, 9498, 53987, 19237, 34384, 41736, 58303, 36635, 42851, 47719, 49177, 49633, 52047, 56660, 54383, 57199, 29021, 55605, 52347, 54232, 50966, 36748, 52935, 41308, 36286, 53684, 47391, 41872, 43405, 33721, 45622, 42649, 50115, 54586, 43888, 47902, 49527, 51410, 58910, 47132, 34648, 29989, 42368, 53708, 53689, 30332, 46468, 53325, 35805, 37677, 56240, 48464, 42005, 8687, 40068, 54998
# ...

# %%
sum = 0

max_sum=0 
sum2=0
sum3=0
intermediate = 0
all_sum =0

total = []

f = open("data.txt", "r")

for i in f:
    if i != "\n":
        sum += int(i)
    else:
        total.append(sum)
        sum = 0

print (total)

for i in range (0,len(total)-1):
    if total[i] > max_sum:
        intermediate = max_sum
        sum3=sum2
        sum2=intermediate
        max_sum = total[i]
    all_sum = max_sum + sum2+ sum3

print (all_sum)
# Out:
# [61970, 52428, 31626, 48210, 60145, 37020, 49032, 46629, 18485, 51703, 57288, 51207, 49586, 57365, 40327, 19535, 34787, 66239, 43148, 57024, 51705, 36761, 57391, 55140, 29288, 41162, 66606, 39859, 53776, 44474, 41504, 40668, 57585, 47552, 46545, 53296, 32949, 38325, 42209, 56391, 42741, 25565, 44563, 45060, 49961, 39613, 42774, 48067, 45671, 31243, 51199, 55550, 29477, 60744, 56591, 58659, 47474, 56887, 48901, 37718, 45512, 26167, 52335, 38888, 19530, 30897, 45583, 54729, 16064, 56843, 51197, 41067, 20546, 32304, 37957, 57943, 30159, 51557, 59642, 55242, 44828, 48560, 45472, 49792, 43225, 45370, 34019, 51977, 9498, 53987, 19237, 34384, 41736, 58303, 36635, 42851, 47719, 49177, 49633, 52047, 56660, 54383, 57199, 29021, 55605, 52347, 54232, 50966, 36748, 52935, 41308, 36286, 53684, 47391, 41872, 43405, 33721, 45622, 42649, 50115, 54586, 43888, 47902, 49527, 51410, 58910, 47132, 34648, 29989, 42368, 53708, 53689, 30332, 46468, 53325, 35805, 37677, 56240, 48464, 42005, 8687, 40068, 54998
# ...
